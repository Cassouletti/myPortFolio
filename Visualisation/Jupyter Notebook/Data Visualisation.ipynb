# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

from matplotlib.ticker import PercentFormatter #converts values into percentage format

# %% [markdown]
# ## Bar Chart

# %%
df_used_cars = pd.read_csv("bar_chart_data.csv")

# %%
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize = (9,4))
plt.bar(x = df_used_cars['Brand'], 
        height = df_used_cars['Cars Listings'],
        #color = ['r', 'g','b','w','y','m','c'])
        color = "midnightblue")
plt.xticks(rotation = 45, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Cars Listings by Brand", 
          fontsize = 16, fontweight = "bold")
plt.ylabel("Number of Listings", fontsize = 13)

plt.show
plt.savefig("Used Cars Bar.png")

# %% [markdown]
# ## Pie Chart

# %%
df_fuel_engine_type = pd.read_csv("pie_chart_data.csv")

# %%
df_fuel_engine_type
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
sns.set_palette('colorblind')

# %%
plt.figure(figsize = (10,8))
plt.pie(df_fuel_engine_type['Number of Cars'],
labels = df_fuel_engine_type['Engine Fuel Type'].values,
autopct = '%.2f%%', textprops = {'size': 'x-large',
                                'fontweight': 'bold',
       'rotation' : 30,
                                'color':'w'})
plt.legend()
plt.title('Cars by engine fuel type', 
          fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## Stacked Area Chart

# %%
def_fuel_engine_type = pd.read_csv('stacked_area_chart_data.csv')

# %%
def_fuel_engine_type
# Out:
#     Year    Gas  Petrol  Diesel  Other
# 0   1982      0      94       0      0
# 1   1983      0     347       0      0
# 2   1984    300       0     334      0
# 3   1985   1030    1184     984      0
# 4   1986    511     681    1066    340
# 5   1987   1817    1840     400    940
# 6   1988   2999    1882    2060      1
# 7   1989   2626    1641    1304    330
# 8   1990   1290    3247       1      0
# 9   1991   1566    6776    1063    400
# 10  1992   2358    1925    2824    350
# 11  1993   1231    3375    2302      0
# 12  1994   2386    5691    2569     77
# 13  1995   2373    5115    4563    666
# 14  1996   4264    6792    6996   1235
# 15  1997   7031    7336    7877    370
# 16  1998   5578    7511    8634    310
# 17  1999   4069    6147   16742   1493
# 18  2000   6459   10754   23102    531
# 19  2001   3932    7590   22115   1029
# 20  2002   3375    7069   18144    479
# 21  2003   6032    8518   19605    281
# 22  2004   8332    7978   17400   1821
# ...

# %%
colors = ['#011638', '#7e2987', '#ef2026']
labels = ['Diesel', 'Petrol', 'Gas']
sns.set_style('white')
plt.figure(figsize = (12,6))
plt.stackplot(def_fuel_engine_type['Year'],
              def_fuel_engine_type['Diesel'],
              def_fuel_engine_type['Petrol'],
              def_fuel_engine_type['Gas'],
              colors = colors,
             edgecolor = 'none')
plt.xticks(def_fuel_engine_type['Year'], rotation = 45)
plt.legend(labels = labels, loc ='upper left')
plt.ylabel('Number of Cars', fontsize = 13)
plt.title("Popularity of Engine Fuel Types (1982 - 2016)",
          fontsize = 14, weight = 'bold')
#sns.despine(left = True, right = True, bottom = True, top = True)
sns.despine()
plt.show()

# %%
# Disel et Petrol étaient très populaires.
# Il y avait peu de donnée avant les 90's car il y a eu une crise 2009-2011.

# %% [markdown]
# ## Line Chart

# %%
def_spx_ftse_00_10 = pd.read_csv('line_chart_data.csv')

# %%
def_spx_ftse_00_10
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
def_spx_ftse_00_10['new_date'] = pd.to_datetime(def_spx_ftse_00_10['Date'])

# %%
labels = ['S&P 500', 'FTSE 100']
plt.figure(figsize = (20,8))
plt.plot(def_spx_ftse_00_10['new_date'],
         def_spx_ftse_00_10['GSPC500'])
plt.plot(def_spx_ftse_00_10['new_date'],
         def_spx_ftse_00_10['FTSE100'])
plt.title('S&P vs FITSE Returns (200 - 2010)', fontsize = 14, fontweight = 'bold')
plt.ylabel("Returns")
plt.xlabel("Date")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %%
def_spx_ftse_00_08 = def_spx_ftse_00_10[(def_spx_ftse_00_10.new_date >= '2008-07-01') 
                                        &(def_spx_ftse_00_10.new_date <= '2008-12-31')]
def_spx_ftse_00_08
# Out:
#             Date   GSPC500   FTSE100   new_date
# 2216    7/1/2008 -0.001072  0.017360 2008-07-01
# 2217    7/2/2008  0.007151 -0.025951 2008-07-02
# 2218    7/3/2008 -0.017779 -0.009781 2008-07-03
# 2219    7/4/2008  0.000000  0.009270 2008-07-04
# 2220    7/7/2008 -0.000048 -0.011650 2008-07-07
# ...          ...       ...       ...        ...
# 2343  12/25/2008  0.000000  0.000000 2008-12-25
# 2344  12/26/2008  0.006529  0.000000 2008-12-26
# 2345  12/29/2008  0.003289  0.000000 2008-12-29
# 2346  12/30/2008 -0.002052  0.024380 2008-12-30
# 2347  12/31/2008  0.022985  0.026578 2008-12-31
#
# [132 rows x 4 columns]

# %%
#labels = ['S&P 500', 'FTSE 100']
plt.figure(figsize = (20,8))
plt.plot(def_spx_ftse_00_08['new_date'],
         def_spx_ftse_00_08['GSPC500'], color = "midnightblue")
plt.plot(def_spx_ftse_00_08['new_date'],
         def_spx_ftse_00_08['FTSE100'], color = "crimson")
plt.title('S&P vs FITSE Returns (H2 2008)', fontsize = 14, fontweight = 'bold')
plt.ylabel("Returns")
plt.xlabel("Date")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %%
# Cette deuxième moitié de 2008 a été turbulante dans la bourse (La grande récession de 2008) .

# %% [markdown]
# ## Histogram

# %%
df_real_estate = pd.read_csv("histogram_data.csv")

# %%
df_real_estate
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# ...

# %%
import numpy as np

sns.set_style("white")
plt.figure(figsize = (8,6))
plt.hist(df_real_estate["Price"], 
         bins = 8,
        color = "#108A99")
plt.title("Distri of Real Estate Prices", fontsize = 14, weight = "bold")
plt.xlabel("Price in (000' $)")
plt.ylabel("Number of Properties")
plt.xticks(np.arange(118, 539, 52.5))
sns.despine()
plt.show()

# %%
import numpy as np
counts, bins = np.histogram(df_real_estate["Price"], bins = 8)
plt.stairs(counts, bins)

# %%
bins
# Out:
# array([118. , 170.5, 223. , 275.5, 328. , 380.5, 433. , 485.5, 538. ])

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# Scatter Plot : Relation entre deux variables numériques.
#
# 2D scatter : Beaucoup de points. Chaque observation est un point sur le chart.
# Ils peuvent réveler une correlation. On peut voir outliers aussi.

# %%
df_real_estate = pd.read_csv("scatter_data.csv")

# %%
df_real_estate
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
plt.figure(figsize = (12,8))
scatterr = plt.scatter(df_real_estate['Area (ft.)'],
            df_real_estate['Price'],
            alpha = 0.6,
            c = df_real_estate['Building Type'],
            cmap = 'viridis')
plt.legend(*scatterr.legend_elements(),
           loc = "upper left",
           title = "Building Type")
plt.title("Relationship between Area and Prince of California Real Estate",
          fontsize = 14,
          weight = "bold")
plt.xlabel("Area (sq. ft.)", weight = "bold")
plt.ylabel("Price (000's of $)")
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(data = df_real_estate,
                x = 'Area (ft.)',
                y = 'Price',
                hue = 'Building Type',
                palette = ['black', 'darkblue', 'purple', 'pink', 'white'],
                s = 100 # Increase each point)
               )
plt.title("Relationship between Area and Prince of California Real Estate",
          fontsize = 14,
          weight = "bold")
plt.xlabel("Area (sq. ft.)", weight = "bold")
plt.ylabel("Price (000's of $)")
plt.show()
# Out:
# /Users/alelia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/alelia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/alelia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Regression Plot

# %%
df_ad = pd.read_csv("scatter_plot_ii.csv")

# %%
df_ad
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
#plt.figure(figsize = (10,8))
sns.set(rc = {'figure.figsize' : (9,6)})
sns.regplot(x = "Budget",
            y = "Sales",
            data = df_ad,
            #color = 'grey',
            scatter_kws = {'color' :'k'},
            line_kws = {'color' : 'red'})
plt.xlabel("Ad Expenditure in (000's $)")
plt.ylabel("Sales in (000's Units)")
plt.title("Effect of Ad Expenditure on Sales",  fontsize = 14, weight ='bold')
plt.show()

# %%
sns.lmplot(x = "Budget",
            y = "Sales",
            data = df_ad,
            height = 10,
            scatter_kws = {'color' :'k'},
            line_kws = {'color' : 'red'})
plt.xlabel("Ad Expenditure in (000's $)")
plt.ylabel("Sales in (000's Units)")
plt.title("Effect of Ad Expenditure on Sales",  fontsize = 14, weight ='bold')
plt.show()

# %% [markdown]
# Si nous disposons d'un budget publicitaire important, nous avons plus de chances d'atteindre un quota de vente plus élevé.
# Plus d'annonces implique plus de ventes. Mais nous savons aussi qu'une augmentation de 50 000 $ des ventes additionnelles se traduirait par environ 2 500 unités supplémentaires vendues.
# f(x) = y.

# %% [markdown]
# ## Bar and Line Chart

# %%
df_kdnuggets = pd.read_csv("bar_line_chart_data.csv")

# %%
df_kdnuggets
# Out:
#    Year  Python Users  Participants
# 0  2012         0.149           798
# 1  2013         0.133          1880
# 2  2014         0.195          3285
# 3  2015         0.303          2800
# 4  2016         0.458          2895
# 5  2017         0.526          2900
# 6  2018         0.656          2300
# 7  2019         0.658          1800

# %%
fig, ax = plt.subplots(figsize = (10,7))

ax.bar(df_kdnuggets['Year'],
       df_kdnuggets['Participants'],
          color = 'k')
ax.set_ylabel("Number of Participants",
              weight = "bold")
ax.tick_params(axis = "y", width = 2, labelsize = "large")

ax1 = ax.twinx()
ax1.set_ylim(0,1)
ax1.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))
ax1.plot(df_kdnuggets['Year'],
         df_kdnuggets['Python Users'],
         color = '#b60000',
         marker = 'D')
ax1.set_ylabel("Python Users", color = "#b60000", weight = 'bold')
ax1.tick_params(axis = "y", colors = "#b60000", width = 2, labelsize = "large")
ax.set_title("KD Nuggets Survey Python users (2012 - 2019)", fontsize = '14', weight = "bold")
# Out:
# Text(0.5, 1.0, 'KD Nuggets Survey Python users (2012 - 2019)')
